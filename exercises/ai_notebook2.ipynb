# %% [markdown]
# # 机器学习基础
# - 机器学习要解决的问题是，基于数据构建合理的统计模型，并利用该模型对数据进行分析和预测

# %% [markdown]
# ### 权重初始化
# 1. 不同的初始化会导致不同的结果，好的初始化可以加快算法收敛速度
# 2. 神经网络不能初始化为零（否则每一层中的每个神经元都会学到相同的东西）
# 3. 将权重初始化为非常大的随机值效果不佳，用小的随机值进行初始化会更好，随机初始化用于破坏对称性

# %% [markdown]
# ### 正则化
# 1. 神经网络模型一般较大，很容易过拟合
# 2.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 卷积CNN
# -
